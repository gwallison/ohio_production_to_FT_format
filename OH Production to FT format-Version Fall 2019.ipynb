# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook contains the code to transform the Excel files available through ODNR (<http://oilandgas.ohiodnr.gov/production>) to a dataset in the same format as Ted's 2016 Production spreadsheet (from a shapefile).
# The data are pretty much copied straight over into separate columns for each ODNR file, but aligned by API number.
#
# See the ODNR Production notebook for an alternate assembly of the data.

# %% [markdown]
# # Steps to update data set

# %% [markdown]
# - Make a copy of this jupyter notebook and make changes to the copy (and keep original separate).
# - Go to <ODNR site with the meta data>(http://oilandgas.ohiodnr.gov/shale) and download the Utica and Marcellus Cumulative Permitting Activity files (the xls versions). Save them in the sources directory.  In the imports code below, change the names of the two files to reflect the downloads.
# - Go to the <ODNR production page>(http://oilandgas.ohiodnr.gov/production) and download all the QUARTERLY data that has been added since the last update.  (Look in sources/odnr_production_files directory on your computer to see what you already have.)  The new files have to be moved to that directory and renamed in the format "YYYY_Q.xls" just like the other files.
# - Go to the "Fetch the Data; concat" section below and add the new filenames to the 'fns' list.
# - Finally, in the Imports section just below, change the name of 'prodcsv' to reflect the last quarter in the new data.
# - That should be it: run this notebook and the output file will show up in the output directory.

# %% [markdown]
# # Imports

# %%
#
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import seaborn as sns

# set datadir to the directory that holds the downloaded files
datadir = './sources/'
outdir = './out/'
indir = datadir+'odnr_production_files/' # subdirectory for the production files

### ODNR cumulative data files.
utica = datadir+'Utica_110219.xlsx'
marcellus = datadir+'Marcellus_110219.xlsx'

prodcsv = outdir+'production_to_2019Q2.csv'
temp = outdir+'temp.csv'
temp2 = outdir+'temp2.csv'

df_allfn = outdir+'df_all.pkl'

# %% [markdown]
# # Fetch the baseline/permit dataset

# %% [markdown]
# The baseline file is used for the metadata such as lat/lon, owner, etc.  It comes from two files on the ODNR page:
# <http://oilandgas.ohiodnr.gov/shale#SHALE>

# %%
####  Read in the ODNR excel sheets

uti = pd.read_excel(utica,header=4,dtype={'API #':'category'})
mar = pd.read_excel(marcellus,header=4,dtype={'API #':'category'})
baseline = pd.concat([uti,mar])
baseline = baseline.dropna()
# rename a few things
baseline.columns = ['PermitDate','County','Township','API','Status','Operator','WellName_Number','SurfLat','SurfLon','EndLat','EndLon']

# print the number of APIs
print(f'Total length = {len(baseline)}')
print(f'Unique API   = {len(baseline["API"].unique())}')
baseline[baseline.API.duplicated()]
# Out:
# Total length = 3275
# Unique API   = 3272
#       PermitDate   County  Township             API     Status  \
# 0  Permit Issued   County  Township           API #     Status
# 7     04/09/2012  BELMONT      MEAD  34013206530000  Producing
# 8     11/19/2018  BELMONT  RICHLAND  34013206620000   Drilling
#
#           Operator     WellName_Number      SurfLat       SurfLon  \
# 0         Operator  Well Name & Number  Surface Lat  Surface Long
# 7  XTO ENERGY INC.           KALDOR 2H   39.9760613   -80.8381833
# 8  XTO ENERGY INC.        COOK UNIT 1H   40.0003351   -80.8905795
#
#          EndLat         EndLon
# 0  Endpoint Lat  Endpoint Long
# 7    39.9698310    -80.8196450
# 8    39.9882041    -80.8680388

# %% [markdown]
# ## Filling in the gaps of the metadata

# %% [markdown]
# Unfortunately, currently (11/2019) the ODNR permit dataset does not include all wells that are listed in the production dataset.  Therefore, we will pull in metadata directly from the production set (even though it is not as complete) and add it to the baseline set for those wells missing from the baseline.
#
# First, we will pull in all the production data and concat to a single dataframe.

# %%
#  The files from 2011 and 2012 are a different format and order so we need different sets of column names.

colnames1 = ['APINumber','Yr','Q','Operator','County','Township','WellName','WellNum','Oil','Gas','Brine','Days']
colnames2 = ['Yr','Q','Operator','County','APINumber','Township','WellName','Oil','Gas','Brine','Days','FirstDate']

dlst = []
filelist = os.listdir(indir)

for f in filelist:
    d = pd.read_excel(indir+f)
    if f[:4] in ['2011','2012']:
        # Need to treat these years differently because they are annual data and slightly diff format
        d.columns = colnames2
        d['Year'] = f[:4]
        d['Quarter'] = '1' 
        d['period'] = f[:4]+'Q1'
    else:
        # The quarterly data doesn't need as much...
        d.columns = colnames1
        d['Year'] = f[:4]
        d['Quarter'] = f[5]
        d['period'] = f[:6].replace('_','Q')
    d = d.filter(['APINumber','Year','Quarter','Operator','County','Township','Wellname','Oil','Gas','Brine','Days','period'])
    
    d.APINumber = d.APINumber.fillna(0).astype('int64').astype(str)
    dlst.append(d)
df_all = pd.concat(dlst,sort=True,ignore_index=True)
df_all.to_pickle(df_allfn)
df_all.head(20)
# Out:
#          APINumber    Brine      County   Days        Gas      Oil  \
# 0   34067210570100   8937.0    HARRISON  198.0  1523465.0  13472.0
# 1   34019220730100  23585.0     CARROLL  206.0   322435.0  12334.0
# 2   34019220850000   2010.0     CARROLL    5.0        0.0    654.0
# 3   34019220810100  10263.0     CARROLL   11.0        0.0    818.0
# 4   34019220740000   2403.0     CARROLL   53.0   137192.0   2167.0
# 5   34099231350100   8389.0    MAHONING   79.0        0.0    758.0
# 6   34133244200100   1796.0     PORTAGE   20.0        0.0    583.0
# 7   34019220760100   9102.0     CARROLL   92.0   183142.0   6096.0
# 8   34019220750000   9519.0     CARROLL  130.0   395290.0   9444.0
# 9   34019221100000   7217.0     CARROLL   52.0    56364.0  11760.0
# 10  34019220850000  17082.0     CARROLL  206.0   332445.0  46914.0
# 11  34019220810100  20325.0     CARROLL  306.0   344387.0  24313.0
# 12  34019220840100   4929.0     CARROLL  119.0   360575.0  15210.0
# 13  34019221030000   9682.0     CARROLL  168.0   349980.0   4852.0
# 14  34019221040000   6127.0     CARROLL  166.0   212812.0   1409.0
# 15  34019221210000   4846.0     CARROLL   18.0    41073.0    982.0
# 16  34019220740000  11231.0     CARROLL  231.0   539293.0   5501.0
# 17  34029217340000   6545.0  COLUMBIANA    4.0        0.0    308.0
# 18  34029216940100  12752.0  COLUMBIANA  204.0    54730.0   8833.0
# 19  34019220900100   6627.0     CARROLL   75.0   297456.0      0.0
#
#                       Operator Quarter    Township  Year  period
# 0    CHESAPEAKE APPALACHIA LLC       1      ARCHER  2011  2011Q1
# 1    CHESAPEAKE APPALACHIA LLC       1     AUGUSTA  2011  2011Q1
# 2    CHESAPEAKE APPALACHIA LLC       1      CENTER  2011  2011Q1
# 3    CHESAPEAKE APPALACHIA LLC       1      CENTER  2011  2011Q1
# 4    CHESAPEAKE APPALACHIA LLC       1        EAST  2011  2011Q1
# 5    CHESAPEAKE APPALACHIA LLC       1      MILTON  2011  2011Q1
# 6    CHESAPEAKE APPALACHIA LLC       1    SUFFIELD  2011  2011Q1
# 7    CHESAPEAKE APPALACHIA LLC       1  WASHINGTON  2011  2011Q1
# 8    CHESAPEAKE APPALACHIA LLC       1  WASHINGTON  2011  2011Q1
# 9   CHESAPEAKE EXPLORATION LLC       1      CENTER  2012  2012Q1
# 10  CHESAPEAKE EXPLORATION LLC       1      CENTER  2012  2012Q1
# 11  CHESAPEAKE EXPLORATION LLC       1      CENTER  2012  2012Q1
# 12  CHESAPEAKE EXPLORATION LLC       1        EAST  2012  2012Q1
# 13  CHESAPEAKE EXPLORATION LLC       1        EAST  2012  2012Q1
# 14  CHESAPEAKE EXPLORATION LLC       1        EAST  2012  2012Q1
# 15  CHESAPEAKE EXPLORATION LLC       1        EAST  2012  2012Q1
# 16  CHESAPEAKE EXPLORATION LLC       1        EAST  2012  2012Q1
# 17  CHESAPEAKE EXPLORATION LLC       1     HANOVER  2012  2012Q1
# 18  CHESAPEAKE EXPLORATION LLC       1        KNOX  2012  2012Q1
# 19  CHESAPEAKE EXPLORATION LLC       1         LEE  2012  2012Q1

# %%
df_all = pd.read_pickle(df_allfn)

API = pd.DataFrame(df_all['APINumber'].unique(),columns=['API'])
mg = pd.merge(baseline,API,left_on='API',right_on='API',how='outer',indicator=True)

# the following df has the API of the not-baseline-included wells.
ext_API = pd.DataFrame(mg[mg['_merge']=='right_only']).filter(['API'],axis=1)

#now let's get the metadata from df_all
df_tmp = df_all.groupby('APINumber',as_index=False)['Operator','County','Township'].last()
meta = pd.merge(df_tmp,ext_API,left_on='APINumber',right_on='API',how='inner')
meta = meta.filter(['API','Operator','County','Township']) #.dropna()
meta
# Out:
#                API                     Operator      County      Township
# 0                0                          NaN         NaN           NaN
# 1   34013209630000   ASCENT RESOURCES UTICA LLC     BELMONT      WHEELING
# 2   34013211170000          RICE DRILLING D LLC     BELMONT          MEAD
# 3   34013212350000      GULFPORT APPALACHIA LLC     BELMONT          MEAD
# 4   34059242760100  PIN OAK ENERGY PARTNERS LLC    GUERNSEY       SPENCER
# 5   34059243100100  PIN OAK ENERGY PARTNERS LLC    GUERNSEY       SPENCER
# 6   34067211610000       CHEVRON APPALACHIA LLC    HARRISON        MONROE
# 7   34067212010000   CHESAPEAKE EXPLORATION LLC    HARRISON        ARCHER
# 8   34067214140000       CHEVRON APPALACHIA LLC    HARRISON    WASHINGTON
# 9   34081205310000   CHESAPEAKE EXPLORATION LLC   JEFFERSON  ISLAND CREEK
# 10  34081207820000   ASCENT RESOURCES UTICA LLC   JEFFERSON  MT. PLEASANT
# 11  34111245150000       Eclipse Resources I LP      MONROE         ADAMS
# 12  34111245700000       ECLIPSE RESOURCES I LP      MONROE   SWITZERLAND
# 13  34111248230000            TRIAD HUNTER  LLC      MONROE        BENTON
# 14  34121245190000   ASCENT RESOURCES UTICA LLC       NOBLE        MARION
# 15  34133244400000     MOUNTAINEER KEYSTONE LLC     PORTAGE       WINDHAM
# 16  34167297200000            TRIAD HUNTER  LLC  WASHINGTON      AURELIUS
# 17  34167297610000               PDC ENERGY INC  WASHINGTON     WATERFORD

# %%
#Fill in with NaN 
bl = pd.concat([baseline,meta],sort=False,ignore_index=True)
bl.fillna(np.NaN,inplace=True)
bl.tail(10)
# Out:
#      PermitDate      County      Township             API Status  \
# 3283        NaN    HARRISON    WASHINGTON  34067214140000    NaN
# 3284        NaN   JEFFERSON  ISLAND CREEK  34081205310000    NaN
# 3285        NaN   JEFFERSON  MT. PLEASANT  34081207820000    NaN
# 3286        NaN      MONROE         ADAMS  34111245150000    NaN
# 3287        NaN      MONROE   SWITZERLAND  34111245700000    NaN
# 3288        NaN      MONROE        BENTON  34111248230000    NaN
# 3289        NaN       NOBLE        MARION  34121245190000    NaN
# 3290        NaN     PORTAGE       WINDHAM  34133244400000    NaN
# 3291        NaN  WASHINGTON      AURELIUS  34167297200000    NaN
# 3292        NaN  WASHINGTON     WATERFORD  34167297610000    NaN
#
#                         Operator WellName_Number SurfLat SurfLon EndLat EndLon
# 3283      CHEVRON APPALACHIA LLC             NaN     NaN     NaN    NaN    NaN
# 3284  CHESAPEAKE EXPLORATION LLC             NaN     NaN     NaN    NaN    NaN
# 3285  ASCENT RESOURCES UTICA LLC             NaN     NaN     NaN    NaN    NaN
# 3286      Eclipse Resources I LP             NaN     NaN     NaN    NaN    NaN
# 3287      ECLIPSE RESOURCES I LP             NaN     NaN     NaN    NaN    NaN
# 3288           TRIAD HUNTER  LLC             NaN     NaN     NaN    NaN    NaN
# 3289  ASCENT RESOURCES UTICA LLC             NaN     NaN     NaN    NaN    NaN
# 3290    MOUNTAINEER KEYSTONE LLC             NaN     NaN     NaN    NaN    NaN
# 3291           TRIAD HUNTER  LLC             NaN     NaN     NaN    NaN    NaN
# 3292              PDC ENERGY INC             NaN     NaN     NaN    NaN    NaN

# %% [markdown]
# # Fetch the data; concat

# %% [markdown]
# Because the data in the files from ODNR is not exactly consistent, We must name the files by hand and use the name of those files as info for the resulting dataframe.  Specifically, name files downloaded : 'YEAR_Q.extension'.  Keep the same extension as the downloaded file (xls or xslx). Add the name to the "fns" variable below.  This program will use the Year and Q info to label the records in the dataframe.  Note that files for years 2011 and 2012 contain annual data only.

# %%
blcop = bl.copy()
fns = ['2011.xls','2012.xls',
      '2013_1.xlsx','2013_2.xlsx','2013_3.xlsx','2013_4.xlsx',
      '2014_1.xls','2014_2.xls','2014_3.xls','2014_4.xls',
      '2015_1.xls','2015_2.xls','2015_3.xls','2015_4.xls',
      '2016_1.xls','2016_2.xls','2016_3.xls','2016_4.xls',
      '2017_1.xls','2017_2.xls','2017_3.xls','2017_4.xls',
      '2018_1.xls','2018_2.xls','2018_3.xls','2018_4.xls',
      '2019_1.xls','2019_2.xls']

#  The files from 2011 and 2012 are a different format and order so we need different sets of column names.

colnames1 = ['APINumber','Yr','Q','Owner','County','Twp','WellName','WellNum','Oil','Gas','Brine','Days']
colnames2 = ['Yr','Q','Owner','County','APINumber','Twp','WellName-WellNum','Oil','Gas','Brine','Days','FirstDate']

def update_col(indx,cols):
    # add the index to the name of each column (except the first (API))
    new = [cols[0]]
    for c in cols[1:]: # skip the first value, it is the API number
        new.append(c+str(indx))
    return new


for i,f in enumerate(fns):
    d = pd.read_excel(indir+f) #,dtype={'Permit Number':'category'})

    if f[:4] in ['2011','2012']:  # 2011 and 2012 are odd and have to be treated separately
        d.columns = colnames2
        d['Year'] = f[:4]
        kcols = ['APINumber','Year','Oil','Gas','Brine','Days']
        d = d.filter(kcols)
        if f[:4]=='2012':  #need to add '1'
            kcols = update_col(i,kcols)
            d.columns = kcols
        d.APINumber = d.APINumber.fillna(0).astype('int64').astype(str)

    else:  # all the other files
        d.columns = colnames1
        d['Year'] = f[:4]
        d['Quarter'] = f[5]
        kcols = ['APINumber','Year','Quarter','Oil','Gas','Brine','Days']
        d.APINumber = d.APINumber.fillna(0).astype('int64').astype(str)
        # some quarters have more than one record for an API - looks like the owner channges hands
        # mid-quarter.  Summing the duplicates (incl # days) solves the issue.
        d = d.groupby(['APINumber','Year','Quarter'],as_index=False)['Oil','Gas','Brine','Days'].sum()
        d = d.filter(kcols)
        kcols = update_col(i,kcols)
        d.columns = kcols

    blcop = blcop.merge(d,how='outer',left_on='API',right_on='APINumber')
    blcop = blcop.drop('APINumber',axis=1)

# %% [markdown]
# # Summary columns

# %%
summ = df_all.groupby('APINumber',as_index=False)['Oil','Gas','Brine','Days'].sum()
summ.columns = ['APINumber','TotalOil','TotalGas','TotalBrine','TotalDays']
blcop = blcop.merge(summ,how='inner',left_on='API',right_on='APINumber')
blcop = blcop.drop('APINumber',axis=1)

blcop['OilPerDay'] = blcop.TotalOil/blcop.TotalDays
blcop['GasPerDay'] = blcop.TotalGas/blcop.TotalDays
blcop['BrinePerDay'] = blcop.TotalBrine/blcop.TotalDays

#print(blcop[blcop.API.duplicated()])
blcop = blcop.drop_duplicates()

# gpk = pd.read_csv(PeakStats)
# blcop = blcop.merge(gpk,left_index=True,right_index=True,how='inner')
# blcop = blcop.drop('Unnamed: 0',axis=1)
blcop.to_csv(prodcsv)
blcop.head(20)
# Out:
#     PermitDate   County     Township             API     Status  \
# 0   11/02/2011  ASHLAND  CLEAR CREEK  34005241600100    Drilled
# 1   04/09/2012  BELMONT         MEAD  34013206530000  Producing
# 3   04/09/2012  BELMONT         MEAD  34013206540100  Producing
# 4   06/15/2012  BELMONT     KIRKWOOD  34013206570100  Producing
# 5   06/21/2012  BELMONT       WARREN  34013206580100  Producing
# 6   03/21/2012  BELMONT     WHEELING  34013206600100  Producing
# 7   03/07/2013  BELMONT     RICHLAND  34013206610000  Producing
# 8   07/28/2014  BELMONT        UNION  34013206680100  Producing
# 9   09/07/2012  BELMONT     SOMERSET  34013206700100  Producing
# 10  12/11/2012  BELMONT     SOMERSET  34013206720000  Producing
# 11  10/12/2012  BELMONT     WHEELING  34013206730000  Producing
# 12  06/12/2013  BELMONT     SOMERSET  34013206740000  Producing
# 13  01/09/2013  BELMONT   WASHINGTON  34013206750100  Producing
# 14  02/06/2013  BELMONT     SOMERSET  34013206770000  Producing
# 15  01/03/2013  BELMONT     RICHLAND  34013206790000  Producing
# 16  01/11/2013  BELMONT   WASHINGTON  34013206800000  Producing
# 17  02/08/2013  BELMONT        UNION  34013206810000  Producing
# 18  11/26/2013  BELMONT     SOMERSET  34013206820000  Producing
# 19  06/17/2013  BELMONT     SOMERSET  34013206830000  Producing
# 20  06/17/2013  BELMONT     SOMERSET  34013206840000  Producing
#
#                          Operator               WellName_Number     SurfLat  \
# 0   DEVON ENERGY PRODUCTION CO LP         EICHELBERGER DAVID 1H  40.9466508
# 1                 XTO ENERGY INC.                     KALDOR 2H  39.9760613
# 3                 XTO ENERGY INC.                     KALDOR 1H  39.9760339
# 4         GULFPORT APPALACHIA LLC                  SHUGERT 1-1H  40.0431192
# 5         GULFPORT APPALACHIA LLC                 SHUGERT 1-12H  40.0326937
# 6      ASCENT RESOURCES UTICA LLC        CAPSTONE HOLDINGS 2H-9  40.1498040
# 7      ASCENT RESOURCES UTICA LLC  PORTERFIELD GAS UNIT C 1H-17  40.0889823
# 8      ASCENT RESOURCES UTICA LLC            BEDWAY N UNN BL 1H  40.0758974
# 9         GULFPORT APPALACHIA LLC                STUTZMAN 1-14H  39.8905635
# 10        GULFPORT APPALACHIA LLC                  MCCORT 1-28H  39.9196305
# 11     ASCENT RESOURCES UTICA LLC        CAPSTONE HOLDINGS 3H-9  40.1498385
# 12        GULFPORT APPALACHIA LLC                  BOLTON 1-29H  39.9384901
# 13        GULFPORT APPALACHIA LLC                    IRONS 1-4H  39.9098242
# 14        GULFPORT APPALACHIA LLC                  MCCORT 2-28H  39.9196658
# 15     ASCENT RESOURCES UTICA LLC            LUDE # 1H-34 1H-34  40.0769680
# 16        GULFPORT APPALACHIA LLC                    IRONS 2-4H  39.9098623
# 17        GULFPORT APPALACHIA LLC             EAGLE CREEK 1-26H  40.0665674
# 18        GULFPORT APPALACHIA LLC                  MCCORT 3-28H  39.9197121
# 19        GULFPORT APPALACHIA LLC                 INHERST 2-14H  39.8893900
# 20        GULFPORT APPALACHIA LLC                 INHERST 1-14H  39.8893894
#
#         SurfLon      EndLat  ...     Gas27 Brine27  Days27  TotalOil  \
# 0   -82.4034777  40.9594639  ...       NaN     NaN     NaN      0.00
# 1   -80.8381833  39.9698310  ...   22842.0   481.0    59.0  29357.33
# 3   -80.8381875  39.9667858  ...   93651.0  4641.0    90.0      0.00
# 4   -81.1231952  40.0574876  ...   38647.0   216.0    91.0   3548.00
# 5   -81.1457695  40.0538862  ...   90005.0  1445.0    91.0  17716.00
# 6   -81.0174046  40.1357399  ...   58050.0   205.0    91.0    871.00
# 7   -80.9331631  40.1041411  ...  108265.0     0.0    83.0      0.00
# 8   -81.0237230  40.0867606  ...  120508.0   890.0    91.0      0.00
# 9   -81.1708906  39.8693232  ...   87395.0   924.0    91.0    422.00
# 10  -81.2152106  39.9377172  ...  100510.0  1024.0    91.0   2131.00
# 11  -81.0173109  40.1365086  ...  143701.0   507.0    91.0    812.00
# 12  -81.2075293  39.9151949  ...   79516.0   527.0    91.0    253.00
# 13  -80.9061902  39.8947274  ...   29200.0   603.0    50.0     21.00
# 14  -81.2151814  39.9435409  ...  129491.0  1070.0    91.0   4328.00
# 15  -80.9974976  40.0917421  ...   52183.0   475.0    42.0     21.00
# 16  -80.9061679  39.8921480  ...   15227.0   116.0    29.0      0.00
# 17  -81.0969212  40.0870810  ...   96630.0   598.0    91.0   6279.00
# 18  -81.2151449  39.9359835  ...   93896.0  1117.0    91.0   2888.00
# 19  -81.1768506  39.8671664  ...  106559.0  1722.0    91.0      0.00
# 20  -81.1767971  39.8689014  ...  101930.0  1678.0    91.0      0.00
#
#      TotalGas  TotalBrine TotalDays  OilPerDay    GasPerDay  BrinePerDay
# 0         0.0    23598.00     102.0   0.000000     0.000000   231.352941
# 1    516920.0    29152.00     924.0  31.772002   559.437229    31.549784
# 3   4553211.0    80707.00    1786.0   0.000000  2549.390258    45.188690
# 4   3454523.0    54912.00    2140.0   1.657944  1614.263084    25.659813
# 5   5995467.0   113085.00    2093.0   8.464405  2864.532728    54.030100
# 6   2472341.0    33692.94    1629.0   0.534684  1517.704727    20.683204
# 7   5523820.0    23041.00    1773.0   0.000000  3115.521715    12.995488
# 8   5280734.0    37264.00    1329.0   0.000000  3973.464259    28.039127
# 9   6567604.0    85002.00    2107.0   0.200285  3117.040342    40.342667
# 10  6625550.0    58757.00    2067.0   1.030963  3205.394291    28.426222
# 11  4623022.0    25808.36    1599.0   0.507817  2891.195747    16.140313
# 12  6223684.0    40995.00    1868.0   0.135439  3331.736617    21.945931
# 13  5164912.0    75167.00    1840.0   0.011413  2807.017391    40.851630
# 14  7966963.0   109538.00    2057.0   2.104035  3873.098201    53.251337
# 15  5695898.0    19379.00    1556.0   0.013496  3660.602828    12.454370
# 16  4232727.0    37210.00    1856.0   0.000000  2280.564116    20.048491
# 17  6652200.0    36090.00    1813.0   3.463320  3669.167126    19.906233
# 18  5609131.0    53332.00    1760.0   1.640909  3187.006250    30.302273
# 19  7571515.0   101977.00    1769.0   0.000000  4280.110232    57.646693
# 20  6387797.0    92542.00    1766.0   0.000000  3617.099094    52.402039
#
# [20 rows x 184 columns]
